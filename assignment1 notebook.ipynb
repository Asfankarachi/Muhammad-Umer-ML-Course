# %% [markdown]
# # Assignment 1 — AI Ethics and Bias Analysis
# **ITAI 4376 | Houston City College | Spring 2026**
#
# Student: Muhammad Umer

# %% [markdown]
# ## Objective
# Analyze sources of algorithmic bias in AI systems and evaluate ethical frameworks and regulatory approaches to promote fairness and accountability.

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print('Environment ready.')

# %% [markdown]
# ## Summary
# This notebook supports the ethics and bias analysis conducted in Assignment 1, documenting findings on algorithmic fairness, bias sources, and mitigation strategies.
