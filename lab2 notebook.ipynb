# %% [markdown]
# # Lab 2 — Applying AI in Healthcare Contexts
# **ITAI 4376 | Houston City College | Spring 2026**
#
# Student: Muhammad Umer

# %% [markdown]
# ## Objective
# Explore how AI and machine learning are applied in healthcare, using synthetic EHR data to demonstrate predictive modeling in clinical contexts.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt

print('Libraries loaded successfully.')

# %% [markdown]
# ## Summary
# This notebook demonstrates how machine learning can be applied to healthcare data, with examples of data preprocessing, model training, and evaluation in a clinical context.
