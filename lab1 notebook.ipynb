# %% [markdown]
# # Lab 1 — Introduction to Machine Learning Concepts
# **ITAI 4376 | Houston City College | Spring 2026**
#
# Student: Muhammad Umer

# %% [markdown]
# ## Objective
# Explore foundational machine learning concepts including supervised learning, model training, and evaluation metrics.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt

print('Libraries loaded successfully.')

# %% [markdown]
# ## Summary
# This notebook demonstrates basic machine learning concepts explored during Lab 1, including data preparation, model training, and evaluation.
